# %%
from Clustering import kmeans,GMM,Hierarchical_clustering,MyDBSCAN

# %%
from sklearn.datasets import make_blobs

# %%
import PIL

# %%
X = make_blobs()[0]

# %%
labels,figure = MyDBSCAN(X,0.8,4)

# %%
figure[-1]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1600x900 at 0x1CB45204DD8>

# %%
Clusters_list,figure = Hierarchical_clustering(X)

# %%
figure[-1]
# Out:
# <PIL.Image.Image image mode=RGB size=2000x900 at 0x1CB6109A160>

# %%
Mu,Sigma,Phi,W,figure = GMM(X,3)

# %%
figure[-1]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1600x900 at 0x1CB041E0C88>

# %%
centroids,labels,figure = kmeans(X,3,1e-4)

# %%
figure[-1]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1600x900 at 0x1CB03406668>
